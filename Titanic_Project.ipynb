# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./Dataset/Titanic_dataset.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Performing EDA on the dataset

# %%
#info function help you to tell all datatypes of column and the null and non-null count
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#describe function provides a quick summary of key statistics
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#columns is use to view all the columnss in the dataset
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
#sort values based on Survived and Sex
data.sort_values(['Survived', 'Sex'])
# Out:
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 18            19         0       3
# 24            25         0       3
# 38            39         0       3
# 40            41         0       3
# ..           ...       ...     ...
# 838          839         1       3
# 839          840         1       1
# 857          858         1       1
# 869          870         1       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#sort values based on Survived and Sex we have done the same thing in this we have assign the ascending to false for sex so instead of woman all 
#the men who survial will show.
data.sort_values(['Survived', 'Sex'], ascending=[True,False])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                               Name     Sex   Age  SibSp  \
# 0                          Braund, Mr. Owen Harris    male  22.0      1
# 4                         Allen, Mr. William Henry    male  35.0      0
# 5                                 Moran, Mr. James    male   NaN      0
# 6                          McCarthy, Mr. Timothy J    male  54.0      0
# 7                   Palsson, Master. Gosta Leonard    male   2.0      3
# ..                                             ...     ...   ...    ...
# ...

# %%
data[data['Age']> 30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Combine both filters to get data for individuals who are under 25 and did not survive 
age = data['Age'] < 25
survived = data['Survived'] == 0
data[age & survived]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0              1         0       3               Braund, Mr. Owen Harris
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 12            13         0       3        Saundercock, Mr. William Henry
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                  Rice, Master. Eugene
# ..           ...       ...     ...                                   ...
# 861          862         0       2           Giles, Mr. Frederick Edward
# 864          865         0       2                Gill, Mr. John William
# 876          877         0       3         Gustafsson, Mr. Alfred Ossian
# 877          878         0       3                  Petroff, Mr. Nedelio
# 882          883         0       3          Dahlberg, Miss. Gerda Ulrika
#
#         Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# ...

# %%
data[data['Pclass'].isin([2,1])]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 9             10         1       2
# 11            12         1       1
# ..           ...       ...     ...
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Select and display the 'Name', 'Age', and 'Sex' columns from the sorted DataFrame  
Age_lt_20 = data[data.Age < 20]
desending_order = Age_lt_20.sort_values('Age', ascending=False)
desending_order[['Name', 'Age', 'Sex']]
# Out:
#                                   Name    Age     Sex
# 887       Graham, Miss. Margaret Edith  19.00  female
# 379        Gustafsson, Mr. Karl Gideon  19.00    male
# 566               Stoytcheff, Mr. Ilia  19.00    male
# 546  Beane, Mrs. Edward (Ethel Clarke)  19.00  female
# 136       Newsom, Miss. Helen Monypeny  19.00  female
# ..                                 ...    ...     ...
# 78       Caldwell, Master. Alden Gates   0.83    male
# 644             Baclini, Miss. Eugenie   0.75  female
# 469      Baclini, Miss. Helene Barbara   0.75  female
# 755          Hamalainen, Master. Viljo   0.67    male
# 803    Thomas, Master. Assad Alexander   0.42    male
#
# [164 rows x 3 columns]

# %% [markdown]
# ### Aggregating Data

# %%
data['Age'].mean()
# Out:
# 29.69911764705882

# %%
data['Age'].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
data.Age.min()
# Out:
# 0.42

# %%
data.Age.max()
# Out:
# 80.0

# %%
data['Age'].quantile()
# Out:
# 28.0

# %% [markdown]
# ### Cumulative Statistics
# - cumsum()
# - cummax()
# - cummin()
# - cumprod()

# %%
pd.DataFrame(data['Survived'].cumsum())
# Out:
#      Survived
# 0           0
# 1           1
# 2           2
# 3           3
# 4           3
# ..        ...
# 886       340
# 887       341
# 888       341
# 889       342
# 890       342
#
# [891 rows x 1 columns]

# %%
pd.DataFrame(data['Survived'].cummin())
# Out:
#      Survived
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 886         0
# 887         0
# 888         0
# 889         0
# 890         0
#
# [891 rows x 1 columns]

# %%
pd.DataFrame(data['Survived'].cummax())
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# ..        ...
# 886         1
# 887         1
# 888         1
# 889         1
# 890         1
#
# [891 rows x 1 columns]

# %%
pd.DataFrame(data['Survived'].cumprod())
# Out:
#      Survived
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 886         0
# 887         0
# 888         0
# 889         0
# 890         0
#
# [891 rows x 1 columns]

# %% [markdown]
# ### Dropping Duplicate

# %%
data.drop_duplicates(subset = ["Pclass", 'SibSp'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 6              7         0       1
# 7              8         0       3
# 9             10         1       2
# 15            16         1       2
# 16            17         0       3
# 27            28         0       1
# 38            39         0       3
# 59            60         0       3
# 120          121         0       2
# 159          160         0       3
# 245          246         0       1
# 726          727         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %% [markdown]
# ### Question
#
# - What is the total number of passengers in each passenger class (Pclass)?
#
# - How many passengers are children (e.g., Age < 18) and how many are adults?
#
# - What is the count of passengers who embarked from each port (Embarked)?
#
# - What are the top 5 highest fares paid, and who paid them (Name, Pclass, and Cabin)?
#
# - How many passengers were assigned to each deck (based on the first letter of Cabin)?

# %%
# What is the total number of passengers in each passenger class (Pclass)?
P_count = data['Pclass'].value_counts()  

plt.bar(P_count.index.astype(str), P_count.values, color='skyblue')  
plt.xlabel('Passenger Class')  
plt.ylabel('Count of Passengers')  
plt.title('Histogram of Passenger Count by Class')  
plt.show()

# %%
# How many passengers are children (e.g., Age < 18) and how many are adults?
Child_count = len(data[data['Age'] <= 18])
print(f"Number of chidrens who are 18 or less in Age: {Child_count}")
# Out:
# Number of chidrens who are 18 or less in Age: 139

# %%
# What is the count of passengers who embarked from each port (Embarked)?
# Southampton (S)
# Cherbourg (C)
# Queenstown (Q)
embarked_count = data['Embarked'].value_counts()
embarked_count
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
Max_fare = data[data['Fare'] == data['Fare'].max()]
result = Max_fare[['Name', 'Pclass', 'Cabin', 'Fare']].head(5)
result
# Out:
#                                    Name  Pclass        Cabin      Fare
# 258                    Ward, Miss. Anna       1          NaN  512.3292
# 679  Cardeza, Mr. Thomas Drake Martinez       1  B51 B53 B55  512.3292
# 737              Lesurer, Mr. Gustave J       1         B101  512.3292

# %%
#How many passengers were assigned to each deck (based on the first letter of Cabin)?
data['Cabin'] = data['Cabin'].dropna().str[0]

#Lineplot
deck_count = data['Cabin'].value_counts()
deck_count.sort_index().plot(kind='line', marker='o')  
plt.title('Number of Passengers Assigned to Each Deck')  
plt.xlabel('Deck')  
plt.ylabel('Number of Passengers')  
plt.grid()  
plt.show()

# %% [markdown]
# ## Notebook End
